# %% [markdown]
# # Starter

# %% [markdown]
# In this code we convert the output of AlphaFold from mmCIF (.CIF) to PDB (.pdb) by using biopython library.

# %%
from Bio.PDB import MMCIFParser, DSSP

# Load mmCIF file
parser = MMCIFParser()
structure = parser.get_structure("model", "../fold_cb513_199/fold_cb513_199_model_0.cif")

# Run DSSP
dssp = DSSP(structure[0], "../fold_cb513_199/fold_cb513_199_model_0.cif", dssp='mkdssp')

# Access secondary structure for each residue
for key in dssp.keys():
    residue = dssp[key]
    print(f"Residue: {residue[0]}, Secondary Structure: {residue[2]}")

# %%
from Bio.PDB import PDBParser, DSSP
from Bio.PDB import MMCIFParser, PDBIO

# Load the mmCIF structure
mmcif_parser = MMCIFParser()
structure = mmcif_parser.get_structure("model", "../fold_cb513_199/fold_cb513_199_model_0.cif")

# Save as PDB
pdb_io = PDBIO()
pdb_io.set_structure(structure)
pdb_io.save("converted.pdb")

# Load PDB structure
parser = PDBParser()
structure = parser.get_structure("model", "converted.pdb")

# Run DSSP
dssp = DSSP(structure[0], "converted.pdb", dssp="mkdssp")

# Access secondary structure for each residue
for key in dssp.keys():
    residue = dssp[key]
    print(f"Residue: {residue[0]}, Secondary Structure: {residue[2]}")
# Out:
# Residue: 1, Secondary Structure: -
# Residue: 2, Secondary Structure: E
# Residue: 3, Secondary Structure: E
# Residue: 4, Secondary Structure: E
# Residue: 5, Secondary Structure: E
# Residue: 6, Secondary Structure: E
# Residue: 7, Secondary Structure: E
# Residue: 8, Secondary Structure: E
# Residue: 9, Secondary Structure: E
# Residue: 10, Secondary Structure: E
# Residue: 11, Secondary Structure: -
# Residue: 12, Secondary Structure: G
# Residue: 13, Secondary Structure: G
# Residue: 14, Secondary Structure: G
# Residue: 15, Secondary Structure: H
# Residue: 16, Secondary Structure: H
# Residue: 17, Secondary Structure: H
# Residue: 18, Secondary Structure: H
# Residue: 19, Secondary Structure: H
# Residue: 20, Secondary Structure: H
# Residue: 21, Secondary Structure: H
# Residue: 22, Secondary Structure: H
# Residue: 23, Secondary Structure: H
# Residue: 24, Secondary Structure: H
# Residue: 25, Secondary Structure: H
# Residue: 26, Secondary Structure: H
# Residue: 27, Secondary Structure: H
# Residue: 28, Secondary Structure: H
# Residue: 29, Secondary Structure: -
# Residue: 30, Secondary Structure: S
# Residue: 31, Secondary Structure: S
# Residue: 32, Secondary Structure: E
# Residue: 33, Secondary Structure: E
# Residue: 34, Secondary Structure: E
# Residue: 35, Secondary Structure: E
# Residue: 36, Secondary Structure: E
# Residue: 37, Secondary Structure: -
# Residue: 38, Secondary Structure: S
# Residue: 39, Secondary Structure: S
# Residue: 40, Secondary Structure: -
# Residue: 41, Secondary Structure: S
# Residue: 42, Secondary Structure: E
# Residue: 43, Secondary Structure: E
# Residue: 44, Secondary Structure: E
# Residue: 45, Secondary Structure: E
# Residue: 46, Secondary Structure: E
# Residue: 47, Secondary Structure: E
# Residue: 48, Secondary Structure: -
# Residue: 49, Secondary Structure: -
